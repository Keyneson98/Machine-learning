# %%
import matplotlib.pyplot as plt
import pandas 
import time
import psutil

# %%
# %matplotlib notebook
plt.rcParams['animation.html']= 'jshtml'

# %%
fig = plt.figure()
ax= fig.add_subplot(111)
fig.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <bound method Figure.show of <Figure size 640x480 with 1 Axes>>

# %%
i=0
x,y= [],[]
while True:
    x.append(i)
    y.append(psutil.cpu_percent())
    
    ax.plot(x,y)
    fig.canvas.draw()
    
    ax.set_xlim(left=max(0, i-50), right= i+50)
    
    time.sleep(0.1)
    i += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\envs\machinelearning\lib\site-packages\PIL\ImageFile.py:495, in _save(im, fp, tile, bufsize)
#     494 try:
# --> 495     fh = fp.fileno()
#     496     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       5 y.append(psutil.cpu_percent())
#       7 ax.plot(x,y)
# ----> 8 fig.canvas.draw()
#      10 ax.set_xlim(left=max(0, i-50), right= i+50)
#      12 time.sleep(0.1)
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\matplotlib\backends\backend_webagg_core.py:190, in FigureCanvasWebAggCore.draw(self)
#     188     super().draw()
#     189 finally:
# --> 190     self.manager.refresh_all()
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\matplotlib\backends\backend_webagg_core.py:496, in FigureManagerWebAgg.refresh_all(self)
#     494 def refresh_all(self):
#     495     if self.web_sockets:
# --> 496         diff = self.canvas.get_diff_image()
#     497         if diff is not None:
#     498             for s in self.web_sockets:
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\matplotlib\backends\backend_webagg_core.py:255, in FigureCanvasWebAggCore.get_diff_image(self)
#     253 data = output.view(dtype=np.uint8).reshape((*output.shape, 4))
#     254 with BytesIO() as png:
# --> 255     Image.fromarray(data).save(png, format="png")
#     256     return png.getvalue()
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\PIL\Image.py:2212, in Image.save(self, fp, format, **params)
#    2209         fp = builtins.open(filename, "w+b")
#    2211 try:
# -> 2212     save_handler(self, fp, filename)
#    2213 finally:
#    2214     # do what we can to clean up
#    2215     if open_fp:
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\PIL\PngImagePlugin.py:1348, in _save(im, fp, filename, chunk, save_all)
#    1346     _write_multiple_frames(im, fp, chunk, rawmode)
#    1347 else:
# -> 1348     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1350 if info:
#    1351     for info_chunk in info.chunks:
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\PIL\ImageFile.py:509, in _save(im, fp, tile, bufsize)
#     507 else:
#     508     while True:
# --> 509         l, s, d = e.encode(bufsize)
#     510         fp.write(d)
#     511         if s:
#
# KeyboardInterrupt:
